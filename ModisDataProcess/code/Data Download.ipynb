# %%
import os
import glob
from IPython.core.display import Image
from pymodis import downmodis

# %%
# destination foldert
dest = 'MOD11A1_11_20'
# tiles to download
tiles = "h11v04"
password = "SSKwz19940211"
user = "wanguigeo"
# starting day
day = "2011-01-01"
# number of day to download
end = "2020-12-31"
delta = 1
modisDown = downmodis.downModis(password=password, user=user, destinationFolder=dest, tiles=tiles, today=day, enddate=end, delta=delta)

# %%
modisDown.connect()
modisDown.downloadsAllDay()
